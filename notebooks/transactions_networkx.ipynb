# %%
import plotly.graph_objects as go
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/DEMO_CALLS/Calls.csv')
df.head()
# Out:
#      Source    Target        Time
# 0  Patricio     Pedro  2019-01-03
# 1  Patricio  Laurence  2019-01-03
# 2     Paolo  Patricio  2019-01-05
# 3      Lino      Lino  2019-01-05
# 4      Lino     Peter  2019-01-06

# %%
G = nx.from_pandas_edgelist(df, source='Source', target='Target')
nx.draw(G)

# %%
persons = list(df.Source)
persons.extend(df.Target)
persons = list(set(persons))
print(persons)
# Out:
# ['Janine', 'Sven', 'Pedro', 'Roland', 'Ann', 'Carine', 'Paolo', 'Francisco', 'Patricio', 'Laurence', 'Victoria', 'Elizabeth', 'Hanna', 'Lino', 'Yang', 'Maria', 'Aria', 'Diego', 'Peter']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# 1. Create the graph
g = nx.from_pandas_edgelist(df, source='Source', target='Target') 

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=50)

# 3. Draw the parts we want
nx.draw_networkx_edges(g, layout, edge_color='#AAAAAA')

#clubs = [node for node in g.nodes() if node in df.club.unique()]
size = [g.degree(node) * 80 for node in g.nodes() if node in persons]
nx.draw_networkx_nodes(g, layout, nodelist=persons, node_size=size, node_color='lightblue')

#people = [node for node in g.nodes() if node in df.name.unique()]
#nx.draw_networkx_nodes(g, layout, nodelist=people, node_size=100, node_color='#AAAAAA')

#high_degree_people = [node for node in g.nodes() if node in df.name.unique() and g.degree(node) > 1]
#nx.draw_networkx_nodes(g, layout, nodelist=high_degree_people, node_size=100, node_color='#fc8d62')

club_dict = dict(zip(persons, persons))
nx.draw_networkx_labels(g, layout, labels=club_dict)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

plt.title("Template")

# 5. Tell matplotlib to show it
plt.show()

# %%
layout = nx.spring_layout(g,iterations=50)
person_size = [g.degree(club) * 80 for club in clubs]

# %%
G1 = nx.DiGraph()
G1.add_nodes_from(persons)
for index, row in df.iterrows():
    G1.add_edge(row.Source, row.Target)
pos = nx.spring_layout(G1)
nx.draw_networkx_nodes(G1, pos)
nx.draw_networkx_labels(G1, pos)
nx.draw_networkx_edges(G1, pos, edge_color='r', arrows = True)

plt.show()

# %%
import plotly.graph_objects as go
import networkx as nx
G = nx.random_geometric_graph(200, 0.125)

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# ...
#  in production, use a production WSGI server like gunicorn instead.
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
